# %% [markdown]
# # 이진분류 종합실습 : 이직 예측

# %% [markdown]
# * 회사 인사팀에서는 AIVLER 들에게 직원의 이직여부과 관련해서 분석을 요청하였습니다.
# * 최근 이직율이 증가하는 것에 대해 우려를 갖고 있기에, 이직여부에 영향을 주는 요인에 대해 분석하여, 이직할 것으로 보이는 직원들에 대해 회사를 떠나지 않도록 인사 프로그램을 준비하려고 합니다.
# * 어떤 직원이 이직할지 예측해 봅시다.

# %% [markdown]
# ![](https://adoptostaging.blob.core.windows.net/media/employee-attrition-reasons-9LIqMv.jpg)

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 함수 만들기

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (2) 데이터 로딩

# %%
# data data
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/Attrition_train_validation.CSV"
data = pd.read_csv(path)
data['Attrition'] = np.where(data['Attrition']=='Yes', 1, 0)
data.head(10)
# Out:
#    Attrition  Age     BusinessTravel              Department  \
# 0          0   33      Travel_Rarely  Research & Development
# 1          0   35  Travel_Frequently  Research & Development
# 2          0   42      Travel_Rarely  Research & Development
# 3          0   46      Travel_Rarely                   Sales
# 4          0   39  Travel_Frequently                   Sales
# 5          1   22  Travel_Frequently  Research & Development
# 6          0   24      Travel_Rarely  Research & Development
# 7          0   34      Travel_Rarely  Research & Development
# 8          0   30      Travel_Rarely  Research & Development
# 9          0   26      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education    EducationField  EmployeeNumber  \
# 0                 7          3           Medical             817
# 1                18          2     Life Sciences            1412
# 2                 6          3           Medical            1911
# 3                 2          3         Marketing            1204
# 4                20          3     Life Sciences            1812
# 5                 4          1  Technical Degree             593
# 6                21          2  Technical Degree            1551
# 7                 8          3           Medical            2068
# 8                20          3             Other            1084
# 9                 6          3     Life Sciences             686
#
#    EnvironmentSatisfaction  Gender  ...  OverTime PercentSalaryHike  \
# 0                        3    Male  ...        No                11
# 1                        3    Male  ...        No                11
# 2                        3    Male  ...        No                13
# 3                        3  Female  ...        No                23
# 4                        3    Male  ...        No                18
# 5                        3    Male  ...        No                16
# 6                        3    Male  ...        No                14
# 7                        2    Male  ...        No                12
# 8                        3    Male  ...        No                15
# 9                        3  Female  ...       Yes                13
#
#    RelationshipSatisfaction StockOptionLevel  TotalWorkingYears  \
# 0                         4                0                 14
# 1                         3                0                 10
# 2                         2                1                 18
# 3                         1                0                 28
# 4                         4                1                  7
# 5                         3                0                  4
# 6                         2                3                  2
# 7                         1                0                  6
# 8                         3                1                  7
# 9                         3                1                  3
#
#    TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                      3               4              13                   9
# 1                      2               3               2                   2
# 2                      3               4              13                   7
# 3                      2               3              26                  15
# 4                      6               3               2                   1
# 5                      3               3               2                   2
# 6                      3               3               1                   1
# 7                      3               4               4                   3
# 8                      1               2               6                   2
# 9                      2               3               3                   2
#
#    YearsWithCurrManager
# 0                     7
# 1                     2
# 2                     7
# 3                     9
# 4                     2
# 5                     2
# 6                     0
# 7                     2
# 8                     2
# 9                     2
#
# [10 rows x 26 columns]

# %% [markdown]
# |	변수 명	|	내용	|	구분	|
# |	----	|	----	|	----	|
# |	**Attrition**	|	이직여부, Yes = 1 , No = 0	|	**Target**	|
# |	Age	|	나이	|	숫자	|
# |	BusinessTravel	|	출장 빈도(범주)	|		|
# |	Department	|	현 부서	|		|
# |	DistanceFromHome	|	집-직장 거리(마일)	|	숫자	|
# |	Education	|	교육수준(범주)	|	1 Below College, 2 College, 3 Bachelor, 4 Master, 5 Doctor	|
# |	EducationField	|	전공	|		|
# |	EmployeeNumber	|	사번	|		|
# |	EnvironmentSatisfaction	|	근무환경에 대한 만족도(범주)	|	1 Low, 2 Good, 3 Excellent, 4 Outstanding	|
# |	Gender	|	성별	|		|
# |	JobInvolvement	|	직무 적극성(참여도)	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	JobRole	|	직무	|		|
# |	JobSatisfaction	|	직무 만족도	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	MaritalStatus	|	결혼상태	| Single, Married, Divorced		|
# |	MonthlyIncome	|	월급	|	숫자	|
# |	NumCompaniesWorked	|	현재까지 근무한 회사 수	|	숫자	|
# |	OverTime	|	야근여부	|	범주	|
# |	PercentSalaryHike	|	전년대비 급여인상율(%)	|	숫자	|
# |	RelationshipSatisfaction	|	동료와의 관계 만족도	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	StockOptionLevel	|	스톡옵션 수준 0~3	|	범주	|
# |	TotalWorkingYears	|	총 근무 연수	|	숫자	|
# |	TrainingTimesLastYear	|	전년 교육훈련 횟수	|	숫자	|
# |	WorkLifeBalance	|	워라밸. 일-삶 균형도	|	1 Bad, 2 Good, 3 Better, 4 Best	|
# |	YearsAtCompany	|	현직장 근무 연수	|	숫자	|
# |	YearsInCurrentRole	|	현직무 연수	|	숫자	|
# |	YearsWithCurrManager	|	현 팀장과 근무한 연수	|	숫자	|

# %% [markdown]
# ----

# %% [markdown]
# ## 2.데이터 전처리

# %% [markdown]
# ### (1) 데이터 정리

# %%
target = 'Attrition'

# %%
# 불필요한 변수 제거
data.drop('EmployeeNumber', axis = 1, inplace = True)

# %%
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# ### (2) 가변수화
# * 범주형 데이터이면서 값이 0,1 로 되어 있는 것이 아니라면, 가변수화를 수행해야 합니다.
# * 대상이 되는 변수에 대해서 가변수화를 수행해주세요.

# %%
dum_cols = ['BusinessTravel','Department','Education','EducationField','EnvironmentSatisfaction','Gender',
            'JobRole', 'JobInvolvement', 'JobSatisfaction', 'MaritalStatus', 'OverTime', 'RelationshipSatisfaction',
            'StockOptionLevel','WorkLifeBalance' ]

x = pd.get_dummies(x, columns = dum_cols ,drop_first = True)
x.head()
# Out:
#    Age  DistanceFromHome  MonthlyIncome  NumCompaniesWorked  \
# 0   33                 7          11691                   0
# 1   35                18           9362                   2
# 2   42                 6          13348                   9
# 3   46                 2          17048                   8
# 4   39                20           4127                   2
#
#    PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 11                 14                      3
# 1                 11                 10                      2
# 2                 13                 18                      3
# 3                 23                 28                      2
# 4                 18                  7                      6
#
#    YearsAtCompany  YearsInCurrentRole  YearsWithCurrManager  ...  \
# 0              13                   9                     7  ...
# 1               2                   2                     2  ...
# 2              13                   7                     7  ...
# 3              26                  15                     9  ...
# 4               2                   1                     2  ...
#
#    OverTime_Yes  RelationshipSatisfaction_2  RelationshipSatisfaction_3  \
# 0             0                           0                           0
# 1             0                           0                           1
# 2             0                           1                           0
# 3             0                           0                           0
# 4             0                           0                           0
#
#    RelationshipSatisfaction_4  StockOptionLevel_1  StockOptionLevel_2  \
# 0                           1                   0                   0
# 1                           0                   0                   0
# 2                           0                   1                   0
# 3                           0                   0                   0
# 4                           1                   1                   0
#
#    StockOptionLevel_3  WorkLifeBalance_2  WorkLifeBalance_3  WorkLifeBalance_4
# 0                   0                  0                  0                  1
# 1                   0                  0                  1                  0
# 2                   0                  0                  0                  1
# 3                   0                  0                  1                  0
# 4                   0                  0                  1                  0
#
# [5 rows x 53 columns]

# %% [markdown]
# ### (3) 데이터 분할
# * train_test_split :
#     * test_size : 0.# - 비율로 분할, 1보다 큰 자연수 - 갯수로 분할
#     * train_size로 지정도 가능.

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = 200, random_state = 2022)

# %% [markdown]
# ### (4) 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ## 4.모델링

# %% [markdown]
# ### (1) 모델1
# * 다양한 구조의 모델 2개 이상을 설계하시오. (히든레이어, 노드 수 조절)

# %%
nfeatures = x_train.shape[1]

# %%
model1 = Sequential([Dense(16, input_shape = (nfeatures,), activation = 'relu'),
                     Dense(8, input_shape = (16,), activation = 'relu'),
                     Dense(1, input_shape = (8,), activation = 'sigmoid')])
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 16)                864
#
#  dense_4 (Dense)             (None, 8)                 136
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1009 (3.94 KB)
# Trainable params: 1009 (3.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model1.compile(optimizer = 'adam', loss = 'binary_crossentropy')

# %%
hist1 = model1.fit(x_train, y_train, epochs = 100, validation_split = 0.2).history
# Out:
# Epoch 1/100
# 27/27 [==============================] - 3s 15ms/step - loss: 0.6701 - val_loss: 0.5904
# Epoch 2/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.5280 - val_loss: 0.4815
# Epoch 3/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4627 - val_loss: 0.4417
# Epoch 4/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4425 - val_loss: 0.4306
# Epoch 5/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4316 - val_loss: 0.4203
# Epoch 6/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4215 - val_loss: 0.4126
# Epoch 7/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4128 - val_loss: 0.4083
# Epoch 8/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4059 - val_loss: 0.4019
# Epoch 9/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3986 - val_loss: 0.3980
# Epoch 10/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3918 - val_loss: 0.3938
# Epoch 11/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3843 - val_loss: 0.3891
# Epoch 12/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3788 - val_loss: 0.3840
# Epoch 13/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3713 - val_loss: 0.3823
# Epoch 14/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3636 - val_loss: 0.3776
# Epoch 15/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3559 - val_loss: 0.3755
# Epoch 16/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3487 - val_loss: 0.3714
# Epoch 17/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3423 - val_loss: 0.3694
# Epoch 18/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3345 - val_loss: 0.3671
# Epoch 19/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3274 - val_loss: 0.3652
# Epoch 20/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3215 - val_loss: 0.3603
# Epoch 21/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3141 - val_loss: 0.3620
# Epoch 22/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3093 - val_loss: 0.3582
# Epoch 23/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3023 - val_loss: 0.3581
# Epoch 24/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2969 - val_loss: 0.3568
# Epoch 25/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2929 - val_loss: 0.3548
# Epoch 26/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2885 - val_loss: 0.3554
# Epoch 27/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2836 - val_loss: 0.3570
# Epoch 28/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2789 - val_loss: 0.3591
# Epoch 29/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2746 - val_loss: 0.3619
# Epoch 30/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2720 - val_loss: 0.3595
# Epoch 31/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2674 - val_loss: 0.3640
# Epoch 32/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2635 - val_loss: 0.3587
# Epoch 33/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2599 - val_loss: 0.3596
# Epoch 34/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2585 - val_loss: 0.3742
# Epoch 35/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2537 - val_loss: 0.3610
# Epoch 36/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2500 - val_loss: 0.3652
# Epoch 37/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2484 - val_loss: 0.3818
# Epoch 38/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2455 - val_loss: 0.3575
# Epoch 39/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2415 - val_loss: 0.3754
# Epoch 40/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2376 - val_loss: 0.3642
# Epoch 41/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2358 - val_loss: 0.3729
# Epoch 42/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2314 - val_loss: 0.3678
# Epoch 43/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2284 - val_loss: 0.3732
# Epoch 44/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2259 - val_loss: 0.3717
# Epoch 45/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2254 - val_loss: 0.3889
# Epoch 46/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2217 - val_loss: 0.3811
# Epoch 47/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2187 - val_loss: 0.3812
# Epoch 48/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2169 - val_loss: 0.3881
# Epoch 49/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2120 - val_loss: 0.3896
# Epoch 50/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2114 - val_loss: 0.3865
# Epoch 51/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2069 - val_loss: 0.3862
# Epoch 52/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.2040 - val_loss: 0.4147
# Epoch 53/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.2005 - val_loss: 0.3851
# Epoch 54/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.1974 - val_loss: 0.3981
# Epoch 55/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1951 - val_loss: 0.3990
# Epoch 56/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1919 - val_loss: 0.4063
# Epoch 57/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1878 - val_loss: 0.4056
# Epoch 58/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1861 - val_loss: 0.4101
# Epoch 59/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1833 - val_loss: 0.4090
# Epoch 60/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1799 - val_loss: 0.4158
# Epoch 61/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1775 - val_loss: 0.4045
# Epoch 62/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1762 - val_loss: 0.4134
# Epoch 63/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1716 - val_loss: 0.4211
# Epoch 64/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1687 - val_loss: 0.4278
# Epoch 65/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1657 - val_loss: 0.4294
# Epoch 66/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1638 - val_loss: 0.4314
# Epoch 67/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1606 - val_loss: 0.4357
# Epoch 68/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1586 - val_loss: 0.4440
# Epoch 69/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1551 - val_loss: 0.4334
# Epoch 70/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1536 - val_loss: 0.4453
# Epoch 71/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1513 - val_loss: 0.4436
# Epoch 72/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1482 - val_loss: 0.4489
# Epoch 73/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1443 - val_loss: 0.4472
# Epoch 74/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1449 - val_loss: 0.4477
# Epoch 75/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1408 - val_loss: 0.4611
# Epoch 76/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1365 - val_loss: 0.4686
# Epoch 77/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1345 - val_loss: 0.4647
# Epoch 78/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1351 - val_loss: 0.4670
# Epoch 79/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1294 - val_loss: 0.4754
# Epoch 80/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1275 - val_loss: 0.4816
# Epoch 81/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1260 - val_loss: 0.4906
# Epoch 82/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1209 - val_loss: 0.4778
# Epoch 83/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1175 - val_loss: 0.5093
# Epoch 84/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1168 - val_loss: 0.5049
# Epoch 85/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1135 - val_loss: 0.5027
# Epoch 86/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1113 - val_loss: 0.5106
# Epoch 87/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1089 - val_loss: 0.5144
# Epoch 88/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1096 - val_loss: 0.5482
# Epoch 89/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1070 - val_loss: 0.5185
# Epoch 90/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1088 - val_loss: 0.5133
# Epoch 91/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1038 - val_loss: 0.5239
# Epoch 92/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0998 - val_loss: 0.5453
# Epoch 93/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0959 - val_loss: 0.5343
# Epoch 94/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0929 - val_loss: 0.5421
# Epoch 95/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0920 - val_loss: 0.5496
# Epoch 96/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0911 - val_loss: 0.5527
# Epoch 97/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0887 - val_loss: 0.5514
# Epoch 98/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0850 - val_loss: 0.5561
# Epoch 99/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0840 - val_loss: 0.5621
# Epoch 100/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0826 - val_loss: 0.5847

# %%
dl_history_plot(hist1)

# %%
pred1 = model1.predict(x_val)
pred1 = np.where(pred1>=0.5, 1, 0)

print(classification_report(y_val, pred1))
# Out:
# 7/7 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       169
#            1       0.65      0.65      0.65        31
#
#     accuracy                           0.89       200
#    macro avg       0.79      0.79      0.79       200
# weighted avg       0.89      0.89      0.89       200

# %% [markdown]
# ### (2) 모델2

# %%
model2 = Sequential([Dense(32, input_shape = (nfeatures,), activation = 'relu'),
                     Dense(16, input_shape = (32,), activation = 'relu'),
                     Dense(8, input_shape = (16,), activation = 'relu'),
                     Dense(1, input_shape = (8,), activation = 'sigmoid')])
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 32)                1728
#
#  dense_7 (Dense)             (None, 16)                528
#
#  dense_8 (Dense)             (None, 8)                 136
#
#  dense_9 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 2401 (9.38 KB)
# Trainable params: 2401 (9.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model2.compile(optimizer = 'adam', loss = 'binary_crossentropy')

# %%
hist2 = model2.fit(x_train, y_train, epochs = 100, validation_split = 0.2).history
# Out:
# Epoch 1/100
# 27/27 [==============================] - 1s 9ms/step - loss: 0.5588 - val_loss: 0.4531
# Epoch 2/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4382 - val_loss: 0.4096
# Epoch 3/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4189 - val_loss: 0.3993
# Epoch 4/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4052 - val_loss: 0.3903
# Epoch 5/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3936 - val_loss: 0.3808
# Epoch 6/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3784 - val_loss: 0.3701
# Epoch 7/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3607 - val_loss: 0.3602
# Epoch 8/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3418 - val_loss: 0.3521
# Epoch 9/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3231 - val_loss: 0.3520
# Epoch 10/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3065 - val_loss: 0.3480
# Epoch 11/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2968 - val_loss: 0.3659
# Epoch 12/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2833 - val_loss: 0.3476
# Epoch 13/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2723 - val_loss: 0.3519
# Epoch 14/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2630 - val_loss: 0.3495
# Epoch 15/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2504 - val_loss: 0.3464
# Epoch 16/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2465 - val_loss: 0.3482
# Epoch 17/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2362 - val_loss: 0.3616
# Epoch 18/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.2263 - val_loss: 0.3589
# Epoch 19/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2207 - val_loss: 0.3602
# Epoch 20/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2112 - val_loss: 0.3613
# Epoch 21/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2044 - val_loss: 0.3638
# Epoch 22/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1983 - val_loss: 0.3618
# Epoch 23/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1903 - val_loss: 0.3668
# Epoch 24/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1805 - val_loss: 0.3868
# Epoch 25/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1739 - val_loss: 0.3892
# Epoch 26/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1681 - val_loss: 0.3890
# Epoch 27/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1604 - val_loss: 0.3920
# Epoch 28/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1533 - val_loss: 0.3919
# Epoch 29/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1470 - val_loss: 0.4103
# Epoch 30/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1382 - val_loss: 0.4059
# Epoch 31/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1336 - val_loss: 0.4180
# Epoch 32/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1259 - val_loss: 0.4376
# Epoch 33/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1192 - val_loss: 0.4303
# Epoch 34/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1139 - val_loss: 0.4435
# Epoch 35/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1101 - val_loss: 0.4529
# Epoch 36/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1020 - val_loss: 0.4447
# Epoch 37/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0980 - val_loss: 0.4873
# Epoch 38/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0932 - val_loss: 0.4907
# Epoch 39/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0872 - val_loss: 0.4835
# Epoch 40/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0815 - val_loss: 0.4956
# Epoch 41/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0788 - val_loss: 0.5298
# Epoch 42/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0755 - val_loss: 0.5143
# Epoch 43/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0700 - val_loss: 0.5253
# Epoch 44/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0669 - val_loss: 0.5305
# Epoch 45/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0646 - val_loss: 0.5476
# Epoch 46/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0605 - val_loss: 0.5571
# Epoch 47/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0563 - val_loss: 0.5697
# Epoch 48/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0540 - val_loss: 0.5753
# Epoch 49/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0514 - val_loss: 0.5857
# Epoch 50/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0474 - val_loss: 0.5970
# Epoch 51/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0444 - val_loss: 0.6104
# Epoch 52/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0445 - val_loss: 0.6349
# Epoch 53/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0390 - val_loss: 0.6553
# Epoch 54/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0372 - val_loss: 0.6843
# Epoch 55/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0337 - val_loss: 0.6844
# Epoch 56/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0294 - val_loss: 0.7129
# Epoch 57/100
# 27/27 [==============================] - 1s 27ms/step - loss: 0.0261 - val_loss: 0.7361
# Epoch 58/100
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0259 - val_loss: 0.7247
# Epoch 59/100
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0219 - val_loss: 0.7473
# Epoch 60/100
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0187 - val_loss: 0.7811
# Epoch 61/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0185 - val_loss: 0.7983
# Epoch 62/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0175 - val_loss: 0.8292
# Epoch 63/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0143 - val_loss: 0.8256
# Epoch 64/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0127 - val_loss: 0.8334
# Epoch 65/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0110 - val_loss: 0.8554
# Epoch 66/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.8774
# Epoch 67/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 0.9078
# Epoch 68/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.9273
# Epoch 69/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.9507
# Epoch 70/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.9519
# Epoch 71/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0048 - val_loss: 0.9677
# Epoch 72/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0042 - val_loss: 0.9792
# Epoch 73/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.9859
# Epoch 74/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0037 - val_loss: 1.0083
# Epoch 75/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0033 - val_loss: 1.0265
# Epoch 76/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 1.0181
# Epoch 77/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0029 - val_loss: 1.0363
# Epoch 78/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 1.0548
# Epoch 79/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0025 - val_loss: 1.0512
# Epoch 80/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 1.0671
# Epoch 81/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 1.0791
# Epoch 82/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 1.0829
# Epoch 83/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 1.0943
# Epoch 84/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 1.1019
# Epoch 85/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 1.1065
# Epoch 86/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 1.1222
# Epoch 87/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 1.1335
# Epoch 88/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 1.1423
# Epoch 89/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 1.1406
# Epoch 90/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 1.1592
# Epoch 91/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 1.1594
# Epoch 92/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 1.1679
# Epoch 93/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 1.1805
# Epoch 94/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 1.1819
# Epoch 95/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 1.1910
# Epoch 96/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 1.1947
# Epoch 97/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 1.2045
# Epoch 98/100
# 27/27 [==============================] - 0s 3ms/step - loss: 9.6888e-04 - val_loss: 1.2111
# Epoch 99/100
# 27/27 [==============================] - 0s 3ms/step - loss: 9.3986e-04 - val_loss: 1.2137
# Epoch 100/100
# 27/27 [==============================] - 0s 4ms/step - loss: 9.1724e-04 - val_loss: 1.2255

# %%
dl_history_plot(hist2)

# %%
pred2 = model2.predict(x_val)
pred2 = np.where(pred2>=0.5, 1, 0)

print(classification_report(y_val, pred2))
# Out:
# 7/7 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91       169
#            1       0.53      0.52      0.52        31
#
#     accuracy                           0.85       200
#    macro avg       0.72      0.72      0.72       200
# weighted avg       0.85      0.85      0.85       200
