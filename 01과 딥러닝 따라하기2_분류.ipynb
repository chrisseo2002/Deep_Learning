# %% [markdown]
# # 딥러닝 따라하기2_분류
#
# * 목적 : 무작정 따라하면서 코드 눈과 손으로 익히기

# %% [markdown]
# # 1.환경준비

# %% [markdown]
# * 라이브러리 Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %% [markdown]
# # 2.Classification : 대학원 지원

# %% [markdown]
# ## (1) 데이터 전처리

# %% [markdown]
# ### 1) 데이터 준비

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/Graduate_apply.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    admit  gre   gpa  rank
# 0      0  380  3.61     3
# 1      1  660  3.67     3
# 2      1  800  4.00     1
# 3      1  640  3.19     4
# 4      0  520  2.93     4

# %%
target = 'admit'
x = data.drop(target, axis=1)
y = data.loc[:, target]

# %% [markdown]
# ### 2) 가변수화

# %% [markdown]
# ### 3) 데이터분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %% [markdown]
# ## (2) 머신러닝 모델링 : 로지스틱회귀

# %%
# 필요한 알고리즘을 불러 옵시다.
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### 1) 모델 선언

# %%
model = LogisticRegression()

# %% [markdown]
# ### 2) 학습

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ### 3) 예측

# %%
pred = model.predict(x_val)

# %% [markdown]
# ### 4) 검증
# 만든 모델은 얼마나 정확한지 검증해 봅시다.

# %%
print(classification_report(y_val, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.87      0.79        55
#            1       0.50      0.28      0.36        25
#
#     accuracy                           0.69        80
#    macro avg       0.61      0.58      0.58        80
# weighted avg       0.66      0.69      0.66        80

# %% [markdown]
# ## (3) 딥러닝 모델링
# * 필요한 함수들 불러오기
# * 모델 선언
# * 학습
# * 예측
# * 성능 검증

# %% [markdown]
# ### 1) 전처리 : Scaling

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### 2) 필요한 함수 불러오기

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.backend import clear_session

# %% [markdown]
# ### 3) 모델 선언

# %%
nfeatures = x_train.shape[1]

# %%
# 메모리 정리
clear_session()

# Sequential 타입 모델 선언
model = Sequential(Dense( 1, input_shape = (nfeatures,), activation = 'sigmoid'))

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 4
#
# =================================================================
# Total params: 4 (16.00 Byte)
# Trainable params: 4 (16.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 컴파일
model.compile(optimizer ='adam', loss = 'binary_crossentropy')

# %% [markdown]
# ### 4) 학습

# %%
hist = model.fit(x_train, y_train, epochs = 50, validation_split = 0.2).history
# Out:
# Epoch 1/50
# 8/8 [==============================] - 2s 74ms/step - loss: 0.6250 - val_loss: 0.6500
# Epoch 2/50
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6218 - val_loss: 0.6507
# Epoch 3/50
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6190 - val_loss: 0.6516
# Epoch 4/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.6162 - val_loss: 0.6525
# Epoch 5/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6133 - val_loss: 0.6534
# Epoch 6/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6109 - val_loss: 0.6544
# Epoch 7/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6083 - val_loss: 0.6553
# Epoch 8/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6064 - val_loss: 0.6565
# Epoch 9/50
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6043 - val_loss: 0.6577
# Epoch 10/50
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6019 - val_loss: 0.6589
# Epoch 11/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6002 - val_loss: 0.6602
# Epoch 12/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5983 - val_loss: 0.6614
# Epoch 13/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5965 - val_loss: 0.6627
# Epoch 14/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5951 - val_loss: 0.6641
# Epoch 15/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5935 - val_loss: 0.6656
# Epoch 16/50
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5920 - val_loss: 0.6670
# Epoch 17/50
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5906 - val_loss: 0.6684
# Epoch 18/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5892 - val_loss: 0.6697
# Epoch 19/50
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5881 - val_loss: 0.6711
# Epoch 20/50
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5869 - val_loss: 0.6724
# Epoch 21/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5860 - val_loss: 0.6739
# Epoch 22/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5849 - val_loss: 0.6754
# Epoch 23/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5840 - val_loss: 0.6768
# Epoch 24/50
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5830 - val_loss: 0.6781
# Epoch 25/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5823 - val_loss: 0.6797
# Epoch 26/50
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5814 - val_loss: 0.6810
# Epoch 27/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5807 - val_loss: 0.6823
# Epoch 28/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5799 - val_loss: 0.6835
# Epoch 29/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5794 - val_loss: 0.6849
# Epoch 30/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5787 - val_loss: 0.6860
# Epoch 31/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5782 - val_loss: 0.6874
# Epoch 32/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5776 - val_loss: 0.6888
# Epoch 33/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5770 - val_loss: 0.6899
# Epoch 34/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5767 - val_loss: 0.6912
# Epoch 35/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5761 - val_loss: 0.6923
# Epoch 36/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5757 - val_loss: 0.6934
# Epoch 37/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5753 - val_loss: 0.6944
# Epoch 38/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5750 - val_loss: 0.6957
# Epoch 39/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5746 - val_loss: 0.6969
# Epoch 40/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5742 - val_loss: 0.6980
# Epoch 41/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5739 - val_loss: 0.6990
# Epoch 42/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5736 - val_loss: 0.6998
# Epoch 43/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5733 - val_loss: 0.7008
# Epoch 44/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5730 - val_loss: 0.7016
# Epoch 45/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5728 - val_loss: 0.7026
# Epoch 46/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5726 - val_loss: 0.7036
# Epoch 47/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5723 - val_loss: 0.7041
# Epoch 48/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5721 - val_loss: 0.7047
# Epoch 49/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5719 - val_loss: 0.7056
# Epoch 50/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5717 - val_loss: 0.7066

# %% [markdown]
# ### 5) 예측

# %%
pred = model.predict(x_val)
pred = np.where(pred>= 0.5, 1, 0)
# Out:
# 3/3 [==============================] - 0s 4ms/step

# %% [markdown]
# ### 6) 검증
# 만든 모델은 얼마나 정확한지 검증해 봅시다.

# %%
print(classification_report(y_val, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83        55
#            1       1.00      0.08      0.15        25
#
#     accuracy                           0.71        80
#    macro avg       0.85      0.54      0.49        80
# weighted avg       0.80      0.71      0.61        80

# %% [markdown]
# # 3.Classification : mobile

# %% [markdown]
# ## (1) 데이터 전처리

# %% [markdown]
# ### 1) 데이터 준비

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/mobile_churn_simple.csv"
data = pd.read_csv(path)
data['CHURN'] = data['CHURN'].map({'STAY':0, 'LEAVE':1})
data.head()
# Out:
#    INCOME  OVERAGE  LEFTOVER   HOUSE  HANDSET_PRICE  \
# 0   31953        0         6  313378            161
# 1   36147        0        13  800586            244
# 2   27273      230         0  305049            201
# 3  120070       38        33  788235            780
# 4   29215      208        85  224784            241
#
#    OVER_15MINS_CALLS_PER_MONTH  AVERAGE_CALL_DURATION  CHURN
# 0                            0                      4      0
# 1                            0                      6      0
# 2                           16                     15      0
# 3                            3                      2      1
# 4                           21                      1      0

# %% [markdown]
# |	구분	|	변수 명	|	내용	|	type	|	비고	|
# |	----	|	----	|	----	|	----	|	----	|
# |	**Target**	|	**CHURN**	|	이탈여부	|	범주	| 0,1	|
# |	feature	|	INCOME	|	소득수준(달러)	|	숫자	|		|
# |	feature	|	OVERAGE	|	월평균 초과사용시간(분)	|	숫자	| |
# |	feature	|	LEFTOVER	|	월평균 잔여시간(%)	|	숫자	| 	|
# |	feature	|	HOUSE	|	집가격(달러)	|	숫자	|	|
# |	feature	|	HANDSET_PRICE	|	휴대폰가격(달러)	|	숫자	|		|
# |	feature	|	OVER_15MINS_CALLS_PER_MONTH	|	월평균 장기통화 횟수	|	숫자	| 		|
# |	feature	|	AVERAGE_CALL_DURATION	|	평균통화시간(분)	|	숫자	|		|

# %%
target = 'CHURN'
x = data.drop(target, axis=1)
y = data.loc[:, target]

# %% [markdown]
# ### 2) 가변수화

# %% [markdown]
# ### 3) 데이터분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %% [markdown]
# ### 4) Scaling

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ## (2) 모델링
# * 필요한 함수들 불러오기
# * 모델 선언
# * 학습
# * 예측
# * 성능 검증

# %%
from keras.models import Sequential
from keras.layers  import Dense
from keras.backend  import clear_session

# %% [markdown]
# ### 1) 모델 선언

# %%
nfeatures = x_train.shape[1]

# %%
# 메모리 정리
clear_session()

# Sequential 타입 모델 선언
model = Sequential(Dense(1, input_shape = (nfeatures,), activation = 'sigmoid'))

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 8
#
# =================================================================
# Total params: 8 (32.00 Byte)
# Trainable params: 8 (32.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 컴파일
model.compile(optimizer = 'adam', loss = 'binary_crossentropy')

# %% [markdown]
# ### 2) 학습

# %%
hist = model.fit(x_train, y_train, validation_split = 0.2, epochs = 100).history
# Out:
# Epoch 1/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.7103 - val_loss: 0.6883
# Epoch 2/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6788 - val_loss: 0.6714
# Epoch 3/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6638 - val_loss: 0.6612
# Epoch 4/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6540 - val_loss: 0.6543
# Epoch 5/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6473 - val_loss: 0.6498
# Epoch 6/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6428 - val_loss: 0.6468
# Epoch 7/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6394 - val_loss: 0.6446
# Epoch 8/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6371 - val_loss: 0.6432
# Epoch 9/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6354 - val_loss: 0.6422
# Epoch 10/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6342 - val_loss: 0.6416
# Epoch 11/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6332 - val_loss: 0.6411
# Epoch 12/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6325 - val_loss: 0.6409
# Epoch 13/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6320 - val_loss: 0.6405
# Epoch 14/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6316 - val_loss: 0.6404
# Epoch 15/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6312 - val_loss: 0.6403
# Epoch 16/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6310 - val_loss: 0.6402
# Epoch 17/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6308 - val_loss: 0.6402
# Epoch 18/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6306 - val_loss: 0.6401
# Epoch 19/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6304 - val_loss: 0.6402
# Epoch 20/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6303 - val_loss: 0.6401
# Epoch 21/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6302 - val_loss: 0.6402
# Epoch 22/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6301 - val_loss: 0.6401
# Epoch 23/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6300 - val_loss: 0.6401
# Epoch 24/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6299 - val_loss: 0.6401
# Epoch 25/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6299 - val_loss: 0.6401
# Epoch 26/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6298 - val_loss: 0.6401
# Epoch 27/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6298 - val_loss: 0.6401
# Epoch 28/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6298 - val_loss: 0.6402
# Epoch 29/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6297 - val_loss: 0.6402
# Epoch 30/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6297 - val_loss: 0.6402
# Epoch 31/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6296 - val_loss: 0.6402
# Epoch 32/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6295 - val_loss: 0.6404
# Epoch 33/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6296 - val_loss: 0.6403
# Epoch 34/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6295 - val_loss: 0.6403
# Epoch 35/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6295 - val_loss: 0.6403
# Epoch 36/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6295 - val_loss: 0.6403
# Epoch 37/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6295 - val_loss: 0.6403
# Epoch 38/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6295 - val_loss: 0.6403
# Epoch 39/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6295 - val_loss: 0.6403
# Epoch 40/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6404
# Epoch 41/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6404
# Epoch 42/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6404
# Epoch 43/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6405
# Epoch 44/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6405
# Epoch 45/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6404
# Epoch 46/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6406
# Epoch 47/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6405
# Epoch 48/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6405
# Epoch 49/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6405
# Epoch 50/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6405
# Epoch 51/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6293 - val_loss: 0.6405
# Epoch 52/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6294 - val_loss: 0.6405
# Epoch 53/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6406
# Epoch 54/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6406
# Epoch 55/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6407
# Epoch 56/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6406
# Epoch 57/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6406
# Epoch 58/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6406
# Epoch 59/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6406
# Epoch 60/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6406
# Epoch 61/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6406
# Epoch 62/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6407
# Epoch 63/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6407
# Epoch 64/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6407
# Epoch 65/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6407
# Epoch 66/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6407
# Epoch 67/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6407
# Epoch 68/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6293 - val_loss: 0.6407
# Epoch 69/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6407
# Epoch 70/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6407
# Epoch 71/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6292 - val_loss: 0.6409
# Epoch 72/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6407
# Epoch 73/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6407
# Epoch 74/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6407
# Epoch 75/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 76/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 77/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 78/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 79/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 80/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 81/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6407
# Epoch 82/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 83/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 84/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 85/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 86/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6408
# Epoch 87/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 88/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 89/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6409
# Epoch 90/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 91/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 92/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 93/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 94/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 95/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 96/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 97/100
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6294 - val_loss: 0.6408
# Epoch 98/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6293 - val_loss: 0.6409
# Epoch 99/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6293 - val_loss: 0.6408
# Epoch 100/100
# 400/400 [==============================] - 1s 3ms/step - loss: 0.6293 - val_loss: 0.6408

# %% [markdown]
# ### 3) 예측

# %%
pred = model.predict(x_val)
# Out:
# 125/125 [==============================] - 0s 1ms/step

# %%
pred = np.where(pred>= 0.5, 1, 0)

# %% [markdown]
# ### 4) 검증
# 만든 모델은 얼마나 정확한지 검증해 봅시다.

# %%
print(classification_report(y_val, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.67      0.66      2038
#            1       0.64      0.61      0.63      1962
#
#     accuracy                           0.64      4000
#    macro avg       0.64      0.64      0.64      4000
# weighted avg       0.64      0.64      0.64      4000
